# %% [markdown]
# #Descrição do Programa - Etapa 2 - Extração de Dados

# %% [markdown]
# #Sincronizando com Google Drive e pasta de trabalho

# %%
from google.colab import drive
from google.colab import output
print('\n! Faça o processo de permissão de sincronização do Drive com o Colab.\n')
drive.mount('/content/drive')
output.clear()
# %cd /content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_2
# Out:
# /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_2

# %% [markdown]
# #Instalando pacotes que serão utilizados

# %%
print('\t--> Iniciando processo de instalação de pacotes que serão utilizados...\n')
try:
  # !pip install -r requirements.txt
except Exception as e:
  output.clear()
  erro = f'{e.__class__.__name__}: {str(e)}'
  print(f'Ocorreu um erro ao instalar os pacotes...\n-->{erro}\n')
else:
  output.clear()
  print('\n\n\tPacotes instalados\n\n')
# Out:
# 	Pacotes instalados

# %% [markdown]
# #Execução do código principal

# %%
import time
from pacote_funcoes.main_function import main

n_programa = 1
n_dia = 4

if n_programa in [1,4]:
    from google.colab import auth
    auth.authenticate_user()
    from googleapiclient.discovery import build
    drive_service = build('drive', 'v3')
else:
    drive_service = None

if __name__ == "__main__":

    main(n_programa=n_programa,n_dia=n_dia,drive_service=drive_service)
# Out:
# 	Variáveis fixas carregadas com sucesso!
#
#
#
# ****************************************************************************************************
# Coleção atual: Direito_Mestrado_Profissional
# Contagem: 1 de 3
# Não achei dic_atualizado, começando um do zero
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 1 de 106...
#
# PDF temporário do Trabalho 1 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 1: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 1 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 2 de 106...
#
# PDF temporário do Trabalho 2 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 2: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 2 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 3 de 106...
#
# PDF temporário do Trabalho 3 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 3: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 3 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 4 de 106...
#
# PDF temporário do Trabalho 4 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 4: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 4 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 5 de 106...
#
# PDF temporário do Trabalho 5 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 5: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 5 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 6 de 106...
#
# PDF temporário do Trabalho 6 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 6: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 6 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 7 de 106...
#
# PDF temporário do Trabalho 7 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 7: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 7 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 8 de 106...
#
# PDF temporário do Trabalho 8 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 8: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2020/Trabalho 8 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 9 de 106...
#
# PDF temporário do Trabalho 9 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 9: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2020/Trabalho 9 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 10 de 106...
#
# PDF temporário do Trabalho 10 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 10: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 10 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 11 de 106...
#
# PDF temporário do Trabalho 11 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 11: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 11 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 12 de 106...
#
# PDF temporário do Trabalho 12 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 12: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 12 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 13 de 106...
#
# PDF temporário do Trabalho 13 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 13: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 13 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 14 de 106...
#
# PDF temporário do Trabalho 14 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 14: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 14 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 15 de 106...
#
# PDF temporário do Trabalho 15 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 15: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 15 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 16 de 106...
#
# PDF temporário do Trabalho 16 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 16: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 16 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 17 de 106...
#
# PDF temporário do Trabalho 17 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 17: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 17 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 18 de 106...
#
# PDF temporário do Trabalho 18 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 18: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 18 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 19 de 106...
#
# PDF temporário do Trabalho 19 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 19: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 19 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 20 de 106...
#
# PDF temporário do Trabalho 20 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 20: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 20 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 21 de 106...
#
# PDF temporário do Trabalho 21 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 21: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 21 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 22 de 106...
#
# PDF temporário do Trabalho 22 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 22: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 22 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 23 de 106...
#
# PDF temporário do Trabalho 23 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 23: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 23 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 24 de 106...
#
# PDF temporário do Trabalho 24 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 24: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 24 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 25 de 106...
#
# PDF temporário do Trabalho 25 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 25: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 25 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 26 de 106...
#
# PDF temporário do Trabalho 26 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 26: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 26 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 27 de 106...
#
# PDF temporário do Trabalho 27 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 27: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 27 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 28 de 106...
#
# PDF temporário do Trabalho 28 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 28: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 28 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 29 de 106...
#
# PDF temporário do Trabalho 29 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 29: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 29 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 30 de 106...
#
# PDF temporário do Trabalho 30 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 30: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 30 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 31 de 106...
#
# PDF temporário do Trabalho 31 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 31: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 31 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 32 de 106...
#
# PDF temporário do Trabalho 32 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 32: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 32 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 33 de 106...
#
# PDF temporário do Trabalho 33 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 33: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 33 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 34 de 106...
#
# PDF temporário do Trabalho 34 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 34: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 34 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 35 de 106...
#
# PDF temporário do Trabalho 35 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 35: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 35 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 36 de 106...
#
# PDF temporário do Trabalho 36 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 36: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 36 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 37 de 106...
#
# PDF temporário do Trabalho 37 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 37: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 37 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 38 de 106...
#
# PDF temporário do Trabalho 38 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 38: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 38 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 39 de 106...
#
# PDF temporário do Trabalho 39 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 39: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 39 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 40 de 106...
#
# PDF temporário do Trabalho 40 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 40: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 40 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 41 de 106...
#
# PDF temporário do Trabalho 41 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 41: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2023/Trabalho 41 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 42 de 106...
#
# PDF temporário do Trabalho 42 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 42: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 42 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 43 de 106...
#
# PDF temporário do Trabalho 43 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 43: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 43 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 44 de 106...
#
# PDF temporário do Trabalho 44 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 44: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 44 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 45 de 106...
#
# PDF temporário do Trabalho 45 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 45: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 45 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 46 de 106...
#
# PDF temporário do Trabalho 46 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 46: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 46 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 47 de 106...
#
# PDF temporário do Trabalho 47 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 47: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 47 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# 	!!!!!!! Lixeira esvaziada com sucesso!
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 48 de 106...
#
# PDF temporário do Trabalho 48 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 48: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 48 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 49 de 106...
#
# PDF temporário do Trabalho 49 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 49: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 49 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 50 de 106...
#
# PDF temporário do Trabalho 50 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 50: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 50 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 51 de 106...
#
# PDF temporário do Trabalho 51 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 51: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 51 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 52 de 106...
#
# PDF temporário do Trabalho 52 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 52: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 52 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 53 de 106...
#
# PDF temporário do Trabalho 53 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 53: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 53 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 54 de 106...
#
# PDF temporário do Trabalho 54 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 54: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 54 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 55 de 106...
#
# PDF temporário do Trabalho 55 da coleção Direito_Mestrado_Profissional criado com sucesso.
#
# ! O texto do PDF não foi extraído: Não foi possível identificar o ano na capa do PDF.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 56 de 106...
#
# PDF temporário do Trabalho 56 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 56: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 56 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 57 de 106...
#
# PDF temporário do Trabalho 57 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 57: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 57 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 58 de 106...
#
# PDF temporário do Trabalho 58 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 58: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 58 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 59 de 106...
#
# PDF temporário do Trabalho 59 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 59: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 59 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 60 de 106...
#
# PDF temporário do Trabalho 60 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 60: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2022/Trabalho 60 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 61 de 106...
#
# PDF temporário do Trabalho 61 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 61: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 61 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 62 de 106...
#
# PDF temporário do Trabalho 62 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 62: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 62 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 63 de 106...
#
# PDF temporário do Trabalho 63 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 63: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 63 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 64 de 106...
#
# PDF temporário do Trabalho 64 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 64: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 64 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 65 de 106...
#
# PDF temporário do Trabalho 65 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 65: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2023/Trabalho 65 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 66 de 106...
#
# PDF temporário do Trabalho 66 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 66: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2019/Trabalho 66 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 67 de 106...
#
# PDF temporário do Trabalho 67 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 67: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2023/Trabalho 67 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 68 de 106...
#
# PDF temporário do Trabalho 68 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 68: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 68 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 69 de 106...
#
# PDF temporário do Trabalho 69 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 69: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2018/Trabalho 69 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 70 de 106...
#
# PDF temporário do Trabalho 70 da coleção Direito_Mestrado_Profissional criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 70: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Direito_Mestrado_Profissional/2021/Trabalho 70 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ...
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 43 de 64...
#
# PDF temporário do Trabalho 43 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 43: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2022/Trabalho 43 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 44 de 64...
#
# PDF temporário do Trabalho 44 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 44: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2022/Trabalho 44 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 45 de 64...
#
# PDF temporário do Trabalho 45 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 45: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2018/Trabalho 45 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 46 de 64...
#
# PDF temporário do Trabalho 46 da coleção Energia_e_Sustentabilidade criado com sucesso.
#
# ! O texto do PDF não foi extraído: Não foi possível identificar o ano na capa do PDF.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 47 de 64...
#
# PDF temporário do Trabalho 47 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 47: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2023/Trabalho 47 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 48 de 64...
#
# PDF temporário do Trabalho 48 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 48: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2023/Trabalho 48 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 49 de 64...
#
# PDF temporário do Trabalho 49 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 49: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2018/Trabalho 49 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# 	!!!!!!! Lixeira esvaziada com sucesso!
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 50 de 64...
#
# PDF temporário do Trabalho 50 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 50: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2020/Trabalho 50 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 51 de 64...
#
# PDF temporário do Trabalho 51 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 51: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2019/Trabalho 51 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 52 de 64...
#
# PDF temporário do Trabalho 52 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 52: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2020/Trabalho 52 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 53 de 64...
#
# PDF temporário do Trabalho 53 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 53: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2019/Trabalho 53 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 54 de 64...
#
# PDF temporário do Trabalho 54 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 54: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2021/Trabalho 54 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 55 de 64...
#
# PDF temporário do Trabalho 55 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 55: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2018/Trabalho 55 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 56 de 64...
#
# PDF temporário do Trabalho 56 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 56: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2021/Trabalho 56 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 57 de 64...
#
# PDF temporário do Trabalho 57 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 57: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2021/Trabalho 57 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 58 de 64...
#
# PDF temporário do Trabalho 58 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 58: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2021/Trabalho 58 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 59 de 64...
#
# PDF temporário do Trabalho 59 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 59: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2022/Trabalho 59 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 60 de 64...
#
# PDF temporário do Trabalho 60 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 60: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2023/Trabalho 60 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 61 de 64...
#
# PDF temporário do Trabalho 61 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 61: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2022/Trabalho 61 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 62 de 64...
#
# PDF temporário do Trabalho 62 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 62: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2022/Trabalho 62 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 63 de 64...
#
# PDF temporário do Trabalho 63 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 63: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2019/Trabalho 63 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
# ----------------------------------------------------------------------------------------------------
# Trabalho 64 de 64...
#
# PDF temporário do Trabalho 64 da coleção Energia_e_Sustentabilidade criado com sucesso.
# Extração do texto concluída com sucesso.
#
# Diretório do trabalho 64: /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções/Energia_e_Sustentabilidade/2020/Trabalho 64 criado com sucesso.
# Texto principal extraído e armazenado com sucessso.
# Notas de rodapé extraídas e armazenadas com sucessso.
#
# PDF temporário excluído com sucesso.
#
#
# 	Duração da execução: 1523,99 segundos.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-85006345c700> in <cell line: 15>()
#      15 if __name__ == "__main__":
#      16
# ---> 17     main(n_programa=n_programa,n_dia=n_dia,drive_service=drive_service)
#
# /content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_2/pacote_funcoes/main_function.py in main(n_programa, n_dia, drive_service)
#     299     caminho_arquivo_fim_de_exec = os.path.join(caminho_pasta_exec,f'Execucao {str(n_programa)}.txt')
#     300
# --> 301     with open(caminho_arquivo_fim_de_exec,'w',encoding='utf-8') as f:
#     302       f.write(f'Fim da exec. {n_programa}.\n\n{txt_exec}')
#     303       f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/.shortcut-targets-by-id/1moyzxkOq1qrb-diJoeaG7k-YGBwXtn7G/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_2/Execs/Dia 4/Execucao 1.txt'
