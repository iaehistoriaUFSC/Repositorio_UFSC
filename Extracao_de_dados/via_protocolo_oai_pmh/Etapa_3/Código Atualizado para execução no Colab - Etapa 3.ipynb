# %% [markdown]
# #Descrição do Programa - Etapa 3 - Extração de Dados

# %% [markdown]
# Neste programa ocorrerá a geração automatizada de uma Planilha de Metadados com status das extrações de texto dos trabalhos e a geração automatizada de um Relatório em PDF dos avisos gerados nas etapas (1 e 2) da Extração de Dados.

# %% [markdown]
# #Sincronizando com Google Drive e pasta de trabalho

# %%
from google.colab import drive
from google.colab import output
print('\n! Faça o processo de permissão de sincronização do Drive com o Colab.\n')
drive.mount('/content/drive')
output.clear()
# %cd /content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_3

# %% [markdown]
# #Instalando pacotes que serão utilizados

# %%
print('\t--> Iniciando processo de instalação de pacotes que serão utilizados...\n')
try:
  # !pip install -r requirements.txt
except Exception as e:
  output.clear()
  erro = f'{e.__class__.__name__}: {str(e)}'
  print(f'Ocorreu um erro ao instalar os pacotes...\n-->{erro}\n')
else:
  output.clear()
  print('\n\n\tPacotes instalados\n\n')

# %% [markdown]
# #Execução do código principal

# %%
import time
from pacote_funcoes.main_function import main

if __name__ == "__main__":
    start = time.time()

    main()

    end = time.time()
    print('\n\n\tDuração total da execução:',round(end-start,2),'segundos.\n')
