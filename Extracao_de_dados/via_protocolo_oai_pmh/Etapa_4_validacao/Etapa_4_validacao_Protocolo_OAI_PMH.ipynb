# %% [markdown]
# #Descrição do Programa - Etapa 4 - Extração de Dados

# %% [markdown]
# **Validação dos resultados da Etapa 2**

# %% [markdown]
# #Validação

# %% [markdown]
# ##Bibliotecas necessárias para validação

# %%
import re
import os
import joblib
from google.colab import drive
# !pip install unidecode
from unidecode import unidecode
drive.mount('/content/drive')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.4 MB/s eta 0:00:00
# ...
# Mounted at /content/drive

# %% [markdown]
# ##Funções necessárias para validação

# %%
def formatarNomeArquivoColecao(nome_colecao : str):
    nome_colecao_formatado = re.sub(r'[^\w]', '_', unidecode(nome_colecao))
    nome_colecao_formatado = nome_colecao_formatado.replace('__','_')
    if nome_colecao_formatado.endswith('_'):
        nome_colecao_formatado = nome_colecao_formatado[:len(nome_colecao_formatado)-1]
    nome_colecao_formatado = nome_colecao_formatado.replace('Programa_de_Pos_Graduacao_em_','')
    return nome_colecao_formatado

def gerarDicionarioDeFalhas(caminho_pasta_dicts_falhas : str) -> dict:
    """
    Organiza todos os dicionários de falhas gerados pelos diferentes programas,
    nos diferentes dias em um só dicionário de falhas contendo todas as
    informações.

    :param caminho_pasta_dicts_falhas: String referente ao caminho até a pasta
    onde está armazenados os arquivos de dicionários de falhas das execuções
    dos programas.
    :return: Dicionário de falhas com todas as coleções e suas respectivas
    informações agrupadas.
    """
    lista_dics_falhas = [os.path.join(caminho_pasta_dicts_falhas,arquivo_dic_falhas) for arquivo_dic_falhas in os.listdir(caminho_pasta_dicts_falhas) if arquivo_dic_falhas.endswith('.joblib')]
    dic_falhas = {'Coleções':{}}
    for arquivo_dic_falhas in lista_dics_falhas:
        dic_falhas_atual = joblib.load(arquivo_dic_falhas)
        for colecao in dic_falhas_atual['Coleções'].keys():
            if colecao not in dic_falhas['Coleções'].keys():
                dic_falhas['Coleções'][colecao] = dic_falhas_atual['Coleções'][colecao]
    # joblib.dump(dic_falhas,'dic_falhas.joblib')
    return dic_falhas

caminho_pasta_dicts_falhas = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_2/Dicionário de Falhas'
caminho_pasta_dicts_etapa_1 = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa 1/Dicts'
caminho_pasta_dicts_atualizados = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_2/Dicts atualizados'

# %% [markdown]
# ##Vendo se teve coleção repetida no salvamento de dicts atualizados

# %%
listagem_de_arquivos_dicts_atualizados = sorted([arquivo for arquivo in os.listdir(caminho_pasta_dicts_atualizados) if arquivo.endswith('.joblib')])

# listagem_de_arquivos_dicts_atualizados += [arquivo for arquivo in os.listdir(r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_2/Dicts atualizados') if arquivo.endswith('.joblib')]


lista_contagem = []
colecao_repetida = False
for arquivo in listagem_de_arquivos_dicts_atualizados:
  if arquivo not in lista_contagem:
    lista_contagem.append(arquivo)
  else:
    colecao_repetida = True
    print('Achei um dic de coleção repetido:',arquivo)
print('Quantidades de dics atualizados únicos:',len(lista_contagem))
if colecao_repetida:
  print('Houve arquivo dic repetido.')
else:
  print('Não foi encontrado duplicidade nos arquivos de dics.')

Programa de Pós-Graduação em Saúde Coletiva [339]
Programa de Pós-Graduação em Saúde Mental e Atenção Psicossocial (Mestrado Profissional) [100]
Programa de Pós-Graduação em Saúde Pública [162]
Programa de Pós-Graduação em Serviço Social [285]
Programa de Pós-Graduação em Sociologia e Ciência Política [60]
Programa de Pós-Graduação em Sociologia Política [594]
Programa de Pós-Graduação em Tecnologias da Informação e Comunicação [161]
Programa de Pós-Graduação em Urbanismo, História e Arquitetura da Cidade [130]
Programa de Pós-Graduação Interdisciplinar em Ciências Humanas [256]
Programa de Pós-Graduação Multicêntrico em Ciências Fisiológicas [47]
Programa de Pós-Graduação Multidisciplinar em Saúde (Mestrado Profissional) [27]
Teses e dissertações do Centro de Ciências Agrárias [24]
Teses e dissertações do Centro de Ciências da Saúde [338]
Teses e dissertações do Centro de Ciências Físicas e Matemáticas [449]
Teses e dissertações do Centro de Comunicação e Expressão [423]
Teses e dissertações do Centro de Filosofia e Ciências Humanas [394]
Teses e dissertações do Centro Sócio-Econômico [392]
Teses e dissertações do Centro Tecnológico [2074]
Teses e dissertações não defendidas na UFSC [194]'''

colecoes_txt = [string for string in txt_colecoes.split('\n') if string.strip() != '']
listagem_de_colecoes_e_qtd_respectivas_de_trabalhos = []
for colecao in colecoes_txt:
  index = colecao.find('[') - 1
  nome_colecao_formatado = formatarNomeArquivoColecao(colecao[:index])
  correspondencias = re.search(r'\d+',colecao[index:])
  qtd_trabalhos = correspondencias.group()

  listagem_de_colecoes_e_qtd_respectivas_de_trabalhos.append((nome_colecao_formatado,qtd_trabalhos))

for arquivo in listagem_de_arquivos_dicts_atualizados:
  encontrado = False
  arquivo = arquivo.replace('.joblib','')
  for colecao in listagem_de_colecoes_e_qtd_respectivas_de_trabalhos:
    if arquivo == colecao[0]:
      print(f'Analisados:\n{arquivo}: {len(joblib.load(os.path.join(caminho_pasta_dicts_atualizados,arquivo+".joblib"))["Autor"])}\nEsperado:\n{colecao[0]}: {colecao[1]}')
      print('\n'+'*'*80)
# Out:
# Analisados:
# Administracao: 788
# Esperado:
# Administracao: 788
#
# ********************************************************************************
# Analisados:
# Administracao_Universitaria_Mestrado_Profissional: 292
# Esperado:
# Administracao_Universitaria_Mestrado_Profissional: 292
#
# ********************************************************************************
# Analisados:
# Agroecossistemas: 438
# Esperado:
# Agroecossistemas: 438
#
# ********************************************************************************
# Analisados:
# Agroecossistemas_Mestrado_Profissional: 59
# Esperado:
# Agroecossistemas_Mestrado_Profissional: 59
#
# ********************************************************************************
# Analisados:
# Antropologia_Social: 496
# Esperado:
# Antropologia_Social: 497
#
# ********************************************************************************
# Analisados:
# Aquicultura: 554
# Esperado:
# Aquicultura: 555
#
# ...

# %% [markdown]
# ##**Verificando coleções nos dicionários de FALHAS**

# %%
contagem_colecoes = []
contagem_colecoes_repetidas = []
contagem_dics_falhas_total = []
for arquivo in sorted([arquivo for arquivo in os.listdir(caminho_pasta_dicts_falhas) if arquivo.endswith('.joblib')]):
  dic_falhas_atual = joblib.load(os.path.join(caminho_pasta_dicts_falhas,arquivo))

  for colecao in list(dic_falhas_atual['Coleções'].keys()):
    contagem_dics_falhas_total.append(colecao)
    if colecao not in contagem_colecoes:
      contagem_colecoes.append(colecao)
    else:
      contagem_colecoes_repetidas.append(colecao)

print('Quantidade total de coleções nos arquivos de dicts de falhas:',len(contagem_dics_falhas_total))
print('Quantidade total de coleções ÚNICAS nos arquivos de dicts de falhas:',len(set(contagem_dics_falhas_total)))

if contagem_colecoes_repetidas:
  print('\nColeções repetidas encontradas nos dicionários de falhas:',len(contagem_colecoes_repetidas))
  for colecao_repetida in contagem_colecoes_repetidas:
    print('-',colecao_repetida)

lista_de_colecoes = joblib.load(r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_1/Lista_de_colecoes/lista_de_colecoes.joblib')
colecoes_nao_adicionadas_nas_falhas = []
qtd = 0
print('\n')
for colecao in lista_de_colecoes:
  if colecao[0] not in contagem_colecoes:
    colecoes_nao_adicionadas_nas_falhas.append(colecao[0])

  # if colecao[0] not in contagem_colecoes or colecao[0] == 'Programa de Pós-Graduação em Engenharia Química' or colecao[0] == 'Programa de Pós-Graduação em Educação Física':
  #   print(colecao[0],colecao[2])
    # qtd += colecao[2]
if colecoes_nao_adicionadas_nas_falhas:
  print('\nColeções que não foram adicionadas nas falhas:')
  for colecao in colecoes_nao_adicionadas_nas_falhas:
    print('-',colecao)
  print(qtd,'trabalhos nestas coleções')
# Out:
# Quantidade total de coleções nos arquivos de dicts de falhas: 113
# Quantidade total de coleções ÚNICAS nos arquivos de dicts de falhas: 112
#
# Coleções repetidas encontradas nos dicionários de falhas: 1
# - Programa de Pós-Graduação em Direito (Mestrado Profissional)

# %%
contagem_colecoes = []
contagem_colecoes_repetidas = []
contagem_dics_falhas_total = []
for arquivo in sorted([arquivo for arquivo in os.listdir(caminho_pasta_dicts_falhas) if arquivo.endswith('.joblib')]):
  dic_falhas_atual = joblib.load(os.path.join(caminho_pasta_dicts_falhas,arquivo))

  for colecao in list(dic_falhas_atual['Coleções'].keys()):
    contagem_dics_falhas_total.append(colecao)
    if colecao not in contagem_colecoes:
      contagem_colecoes.append(colecao)
    else:
      contagem_colecoes_repetidas.append(colecao)

    if colecao == 'Programa de Pós-Graduação em Direito (Mestrado Profissional)':
      print('Achei Direito (Mestrado Profissional) em',arquivo)

print('Quantidade total de coleções nos arquivos de dicts de falhas:',len(contagem_dics_falhas_total))
print('Quantidade total de coleções ÚNICAS nos arquivos de dicts de falhas:',len(set(contagem_dics_falhas_total)))

if contagem_colecoes_repetidas:
  print('\nColeções repetidas encontradas nos dicionários de falhas:',len(contagem_colecoes_repetidas))
  for colecao_repetida in contagem_colecoes_repetidas:
    print('-',colecao_repetida)

lista_de_colecoes = joblib.load(r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_1/Lista_de_colecoes/lista_de_colecoes.joblib')
colecoes_nao_adicionadas_nas_falhas = []
qtd = 0
print('\n')
for colecao in lista_de_colecoes:
  if colecao[0] not in contagem_colecoes:
    colecoes_nao_adicionadas_nas_falhas.append(colecao[0])

  # if colecao[0] not in contagem_colecoes or colecao[0] == 'Programa de Pós-Graduação em Engenharia Química' or colecao[0] == 'Programa de Pós-Graduação em Educação Física':
  #   print(colecao[0],colecao[2])
    # qtd += colecao[2]
if colecoes_nao_adicionadas_nas_falhas:
  print('\nColeções que não foram adicionadas nas falhas:')
  for colecao in colecoes_nao_adicionadas_nas_falhas:
    print('-',colecao)
  print(qtd,'trabalhos nestas coleções')
# Out:
# Achei Direito (Mestrado Profissional) em dic_falhas_programa_1_dia_4.joblib
# Achei Direito (Mestrado Profissional) em dic_falhas_programa_3_dia_1.joblib
# Quantidade total de coleções nos arquivos de dicts de falhas: 113
# Quantidade total de coleções ÚNICAS nos arquivos de dicts de falhas: 112
#
# Coleções repetidas encontradas nos dicionários de falhas: 1
# - Programa de Pós-Graduação em Direito (Mestrado Profissional)

# %%
contagem_colecoes = []
contagem_colecoes_repetidas = []
contagem_dics_falhas_total = []
for arquivo in sorted([arquivo for arquivo in os.listdir(caminho_pasta_dicts_falhas) if arquivo.endswith('.joblib')]):
  dic_falhas_atual = joblib.load(os.path.join(caminho_pasta_dicts_falhas,arquivo))

  for colecao in list(dic_falhas_atual['Coleções'].keys()):
    contagem_dics_falhas_total.append(colecao)
    if colecao not in contagem_colecoes:
      contagem_colecoes.append(colecao)
    else:
      contagem_colecoes_repetidas.append(colecao)

    if colecao == 'Programa de Pós-Graduação em Direito (Mestrado Profissional)' and arquivo == 'dic_falhas_programa_3_dia_1.joblib':
      print('Achei Direito (Mestrado Profissional) em',arquivo)
      print('Removendo esta coleção deste dic de falhas...')
      print(dic_falhas_atual)
      del(dic_falhas_atual['Coleções'][colecao])
      print(dic_falhas_atual)
      joblib.dump(dic_falhas_atual,os.path.join(caminho_pasta_dicts_falhas,arquivo))
      print(arquivo,'atualizado\n')

print('Quantidade total de coleções nos arquivos de dicts de falhas:',len(contagem_dics_falhas_total))
print('Quantidade total de coleções ÚNICAS nos arquivos de dicts de falhas:',len(set(contagem_dics_falhas_total)))

if contagem_colecoes_repetidas:
  print('\nColeções repetidas encontradas nos dicionários de falhas:',len(contagem_colecoes_repetidas))
  for colecao_repetida in contagem_colecoes_repetidas:
    print('-',colecao_repetida)

lista_de_colecoes = joblib.load(r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_1/Lista_de_colecoes/lista_de_colecoes.joblib')
colecoes_nao_adicionadas_nas_falhas = []
qtd = 0
print('\n')
for colecao in lista_de_colecoes:
  if colecao[0] not in contagem_colecoes:
    colecoes_nao_adicionadas_nas_falhas.append(colecao[0])

  # if colecao[0] not in contagem_colecoes or colecao[0] == 'Programa de Pós-Graduação em Engenharia Química' or colecao[0] == 'Programa de Pós-Graduação em Educação Física':
  #   print(colecao[0],colecao[2])
    # qtd += colecao[2]
if colecoes_nao_adicionadas_nas_falhas:
  print('\nColeções que não foram adicionadas nas falhas:')
  for colecao in colecoes_nao_adicionadas_nas_falhas:
    print('-',colecao)
  print(qtd,'trabalhos nestas coleções')
# Out:
# Achei Direito (Mestrado Profissional) em dic_falhas_programa_3_dia_1.joblib
# Removendo esta coleção deste dic de falhas...
# ...

# %%
contagem_colecoes = []
contagem_colecoes_repetidas = []
contagem_dics_falhas_total = []
for arquivo in sorted([arquivo for arquivo in os.listdir(caminho_pasta_dicts_falhas) if arquivo.endswith('.joblib')]):
  dic_falhas_atual = joblib.load(os.path.join(caminho_pasta_dicts_falhas,arquivo))

  for colecao in list(dic_falhas_atual['Coleções'].keys()):
    contagem_dics_falhas_total.append(colecao)
    if colecao not in contagem_colecoes:
      contagem_colecoes.append(colecao)
    else:
      contagem_colecoes_repetidas.append(colecao)

print('Quantidade total de coleções nos arquivos de dicts de falhas:',len(contagem_dics_falhas_total))
print('Quantidade total de coleções ÚNICAS nos arquivos de dicts de falhas:',len(set(contagem_dics_falhas_total)))

if contagem_colecoes_repetidas:
  print('\nColeções repetidas encontradas nos dicionários de falhas:',len(contagem_colecoes_repetidas))
  for colecao_repetida in contagem_colecoes_repetidas:
    print('-',colecao_repetida)

lista_de_colecoes = joblib.load(r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_1/Lista_de_colecoes/lista_de_colecoes.joblib')
colecoes_nao_adicionadas_nas_falhas = []
qtd = 0
print('\n')
for colecao in lista_de_colecoes:
  if colecao[0] not in contagem_colecoes:
    colecoes_nao_adicionadas_nas_falhas.append(colecao[0])

  # if colecao[0] not in contagem_colecoes or colecao[0] == 'Programa de Pós-Graduação em Engenharia Química' or colecao[0] == 'Programa de Pós-Graduação em Educação Física':
  #   print(colecao[0],colecao[2])
    # qtd += colecao[2]
if colecoes_nao_adicionadas_nas_falhas:
  print('\nColeções que não foram adicionadas nas falhas:')
  for colecao in colecoes_nao_adicionadas_nas_falhas:
    print('-',colecao)
  print(qtd,'trabalhos nestas coleções')
# Out:
# Quantidade total de coleções nos arquivos de dicts de falhas: 112
# Quantidade total de coleções ÚNICAS nos arquivos de dicts de falhas: 112

# %% [markdown]
# ##Verificando tamanho de linhas e colunas dos dics

# %%
caminho_pasta_dicts_atualizados = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Etapa_2/Dicts atualizados'

dics_atualizados = [arquivo for arquivo in os.listdir(caminho_pasta_dicts_atualizados) if arquivo.endswith('.joblib')]

print('Caso haja alguma incongruência será exibida abaixo:\n')

for dic_atualizado in dics_atualizados:
  # print(os.path.join(caminho_pasta_dicts_atualizados,dic_atualizado))
  try:
    # print('tentando')
    dic_atualizado_atual = joblib.load(os.path.join(caminho_pasta_dicts_atualizados,dic_atualizado))
  except Exception as e:
    print(f'{e.__class__.__name__}:{str(e)}')
  else:
    lista_de_tamanhos = []
    inc = False
    for chave in dic_atualizado_atual.keys():
      tamanho = len(dic_atualizado_atual[chave])
      lista_de_tamanhos.append((chave,tamanho))
      for itens in lista_de_tamanhos:
        if itens[1] != tamanho:

          inc = True
    if inc:
      print(dic_atualizado)
      print('keys',dic_atualizado_atual.keys())

      for itens in lista_de_tamanhos:
        print(itens)
      print('\n\n')
# Out:
# Caso haja alguma incongruência será exibida abaixo:
