# %% [markdown]
# # Objetivo

# %% [markdown]
# > **Programa destinado a contar o número de tokens presentes no corpus adquirido da coleta feita do Repositório Institucional da UFSC.**

# %% [markdown]
# # Preparação do ambiente

# %%
from google.colab import drive
from google.colab import output
drive.mount('/content/drive')
import os
import msgpack
# !pip install ferramentas-basicas-pln -U
from ferramentas_basicas_pln import formatarTexto,removerCaracteresEspeciais,removerCaracteresEstranhos,removerEspacosEmBrancoExtras,transformarTextoSubstituindoCaracteres,coletarTextoDeArquivoTxt
from ferramentas_basicas_pln import STRING_CARACTERES_ESPECIAIS_PADRAO

with open(os.path.join(r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Word Embeddings','Lista de stopwords para pré-processamento - WOKE UFSC.txt'),'r',encoding='utf-8') as f:
  stopwords = f.read()
lista_stopwords = sorted(set([palavra.strip() for palavra in stopwords.split('\n') if not (palavra.startswith('#') or palavra.startswith('-'))]),key=len)
# len(lista_stopwords)
# Out:
# Mounted at /content/drive
# Requirement already satisfied: ferramentas-basicas-pln in /usr/local/lib/python3.10/dist-packages (0.9.9.8)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from ferramentas-basicas-pln) (2023.12.25)

# %% [markdown]
# # Funções

# %%
def salvarNumeroDeTokensDoTrabalho(nome_variavel : str,
                                   variavel_em_questao,
                                   pasta_do_trabalho : str = '') -> tuple[bool,str]:
  try:
      if not os.path.exists(pasta_do_trabalho):
          os.makedirs(pasta_do_trabalho)

      variable_bytes = msgpack.packb(variavel_em_questao)

      if not nome_variavel.endswith('.msgpack'):
          nome_variavel += '.msgpack'

      with open(os.path.join(pasta_do_trabalho,nome_variavel),'wb') as f:
          f.write(variable_bytes)
          f.close()
          return True, f'Variável {nome_variavel} salva com sucesso no formato .msgpack'

  except Exception as e:
      error_message = f'{e.__class__.__name__}: {str(e)}'
      return False, error_message

def obterNumeroDeTokens(texto : str, silencio : bool = True) -> int:
  lista_tokens_crus = [palavra for palavra in padronizacaoTextual(texto).split()]
  if not silencio:
    print('Lista tokens crus:',lista_tokens_crus)
  qtd_tokens_crus = len(lista_tokens_crus)
  qtd_vocab_cru = len(set(lista_tokens_crus))
  if not silencio:
    print('Lista vocab cru:',set(lista_tokens_crus))

  lista_tokens_sem_stopwords = [palavra for palavra in lista_tokens_crus if palavra not in lista_stopwords]
  if not silencio:
    print('Lista tokens sem stopwords:',lista_tokens_sem_stopwords)
  qtd_tokens_sem_stopwords = len(lista_tokens_sem_stopwords)
  qtd_vocab_sem_stopwords = len(set(lista_tokens_sem_stopwords))
  if not silencio:
    print('Lista vocab sem stopwords:',set(lista_tokens_sem_stopwords))
  return {'qtd_tokens_crus':qtd_tokens_crus,'qtd_vocab_cru':qtd_vocab_cru,'qtd_tokens_sem_stopwords':qtd_tokens_sem_stopwords,'qtd_vocab_sem_stopwords':qtd_vocab_sem_stopwords}

def padronizacaoTextual(texto : str):
  return formatarTexto(texto=texto,
                       padronizar_links=True,padrao_link='link_url_mask',
                       padronizar_dinheiros=True,padrao_dinheiro='R$',
                       padronizar_emails=True,padrao_email='e_mail_mask')

def listagemDeTrabalhos(lista_de_trabalhos : list,
                        n_programa : int,
                        numero_max_programas : int = 12) -> list:
  dic_programas_trabalhos = {'Prog 1':[],'Prog 2':[],'Prog 3':[],'Prog 4':[],'Prog 5':[],
                             'Prog 6':[],'Prog 7':[],'Prog 8':[],'Prog 9':[],'Prog 10':[],
                             'Prog 11':[],'Prog 12':[],'Prog 13':[],'Prog 14':[],'Prog 15':[]}
  for i in range(len(lista_de_trabalhos)):
    if (i+1) <= numero_max_programas:
      num = i + 1
      dic_programas_trabalhos[f'Prog {num}'].append(lista_de_trabalhos[i])
    else:
      if (i+1)%numero_max_programas != 0:
        num = (i+1)%numero_max_programas
        dic_programas_trabalhos[f'Prog {num}'].append(lista_de_trabalhos[i])
      else:
        num = numero_max_programas
        dic_programas_trabalhos[f'Prog {num}'].append(lista_de_trabalhos[i])
  return dic_programas_trabalhos[f'Prog {n_programa}']

def atualizarConsole(nova_string : str) -> None:
  output.clear()
  print(nova_string)

def openMsgPackFile(full_filepath : str,
                    encoding_type : str = None):
    if not full_filepath.endswith('.msgpack'):
        full_filepath += '.msgpack'
    if encoding_type:
        with open(full_filepath,'rb',encoding=encoding_type) as f:
            variable_bytes = f.read()
            variable_loaded = msgpack.unpackb(variable_bytes, raw=False)
            f.close()
            return variable_loaded
    else:
        with open(full_filepath,'rb') as f:
            variable_bytes = f.read()
            variable_loaded = msgpack.unpackb(variable_bytes, raw=False)
            f.close()
            return variable_loaded

# %% [markdown]
# # Execução

# %%
caminho_colecoes_extracao_textos = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções'

caminho_colecoes_word_embeddings = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Word Embeddings/Textos_tokenizados/Colecoes'

lista_de_colecoes_extracao = [os.path.join(caminho_colecoes_extracao_textos,colecao) for colecao in os.listdir(caminho_colecoes_extracao_textos) if ('.' not in colecao)]

lista_nomes_colecoes_extracao = [os.path.basename(colecao) for colecao in lista_de_colecoes_extracao]

dic_colecoes_extracao = {chave: valor for chave, valor in zip(lista_nomes_colecoes_extracao, lista_de_colecoes_extracao)}

n_programa = 1

string_console = f'Programa {n_programa}\n\n'

for nome_colecao in sorted(dic_colecoes_extracao.keys()):

  print('\n'+'-'*100+'\n'+f'Coleção: {nome_colecao}\n'+'-'*100+'\n')
  colecao = dic_colecoes_extracao[nome_colecao]
  lista_de_anos_colecao_extracao = sorted([os.path.join(colecao,ano) for ano in os.listdir(colecao) if ano.isdigit()])

  string_console += f'{nome_colecao}: OK\n'

  for ano in lista_de_anos_colecao_extracao:

    print(f'Ano: {os.path.basename(ano)}\n')

    lista_trabalhos_ano_colecao_extracao = sorted([os.path.join(ano,trabalho) for trabalho in os.listdir(ano) if trabalho.startswith('Trabalho')])

    if len(lista_trabalhos_ano_colecao_extracao) >= n_programa:

      lista_de_trabalhos_para_este_programa = listagemDeTrabalhos(lista_de_trabalhos=lista_trabalhos_ano_colecao_extracao,n_programa=n_programa)

      for trabalho in lista_de_trabalhos_para_este_programa:
        print(f'{os.path.basename(trabalho)}: ')
        lista_arquivos_trabalho_ano_colecao_extracao = [os.path.join(trabalho,arquivo) for arquivo in os.listdir(trabalho) if arquivo in ['notas_de_rodape.txt','texto_principal.txt']]
        txt_total = ''
        for arquivo in lista_arquivos_trabalho_ano_colecao_extracao:
          try:
            txt_total += coletarTextoDeArquivoTxt(caminho_arquivo=arquivo,tipo_de_encoding='utf-8')+'.  '
          except Exception as e:
            print(f'\n! Problema ao abrir arquivo de texto: {e.__class__.__name__}: {str(e)}.\n{trabalho},{ano},{nome_colecao}.\n')
        if txt_total.strip() != '':
          dic_numero_tokens = obterNumeroDeTokens(txt_total)
          caminho_pasta_salvar_pre_processamento = os.path.join(caminho_colecoes_word_embeddings,os.path.basename(colecao),os.path.basename(ano),os.path.basename(trabalho))

          print(salvarNumeroDeTokensDoTrabalho(nome_variavel='dic_numero_tokens',variavel_em_questao=dic_numero_tokens,pasta_do_trabalho=caminho_pasta_salvar_pre_processamento))
    string_console += f'Ano: {os.path.basename(ano)}: OK\n\n'
  atualizarConsole(string_console)
# Out:
# Programa 1
#
# Administracao: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Administracao_Universitaria_Mestrado_Profissional: OK
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Agroecossistemas: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Agroecossistemas_Mestrado_Profissional: OK
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Antropologia_Social: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Aquicultura: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Arquitetura_e_Urbanismo: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Assistencia_Farmaceutica: OK
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Biologia_Celular_e_do_Desenvolvimento: OK
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Biologia_Vegetal: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Biologia_de_Fungos_Algas_e_Plantas: OK
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Bioquimica: OK
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Biotecnologia: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Biotecnologia_e_Biociencias: OK
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ciencia_da_Computacao: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ciencia_da_Informacao: OK
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ciencia_dos_Alimentos: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ciencia_e_Engenharia_de_Materiais: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ciencias_Medicas: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ciencias_da_Reabilitacao: OK
# Ano: 2009: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Contabilidade: OK
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Controle_de_Gestao_Mestrado_Profissional: OK
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Cuidados_Intensivos_e_Paliativos_Mestrado_Profissional: OK
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Desastres_Naturais_Mestrado_Profissional: OK
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Design: OK
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Design_e_Expressao_Grafica: OK
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Direito: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Direito_Mestrado_Profissional: OK
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ecologia: OK
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Economia: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ecossistemas_Agricolas_e_Naturais: OK
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Educacao: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Educacao_Cientifica_e_Tecnologica: OK
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Educacao_Fisica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Energia_e_Sustentabilidade: OK
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Enfermagem: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_Ambiental: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_Ambiental_Mestrado_Profissional: OK
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Engenharia_Civil: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_Eletrica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_Mecanica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_Mecanica_Mestrado_Profissional: OK
# Ano: 2006: OK
#
# Engenharia_Quimica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_Textil: OK
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_de_Alimentos: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_de_Automacao_e_Sistemas: OK
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_de_Producao: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_de_Sistemas_Eletronicos: OK
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_de_Transportes_e_Gestao_Territorial: OK
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_e_Ciencias_Mecanicas: OK
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Engenharia_e_Gestao_do_Conhecimento: OK
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ensino_de_Biologia: OK
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ensino_de_Biologia_Mestrado_Profissional: OK
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2022: OK
#
# Ensino_de_Fisica_Mestrado_Profissional: OK
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ensino_de_Historia_Mestrado_Profissional: OK
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Estudos_da_Traducao: OK
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Farmacia: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Farmacologia: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Farmacologia_Mestrado_Profissional: OK
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Filosofia: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Fisica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Fonoaudiologia: OK
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Geografia: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Geologia: OK
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Gestao_do_Cuidado_em_Enfermagem: OK
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Gestao_do_Cuidado_em_Enfermagem_Mestrado_Profissional: OK
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Historia: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Informatica_em_Saude_Mestrado_Profissional: OK
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Ingles_Estudos_Linguisticos_e_Literarios: OK
# Ano: 2013: OK
#
# Ano: 2022: OK
#
# Jornalismo: OK
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Letras_Ingles_e_Literatura_Correspondente: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Letras_Literatura_Brasileira: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Letras_Mestrado_Profissional: OK
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Linguistica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Literatura: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Matematica_Mestrado_Profissional: OK
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Matematica_Pura_e_Aplicada: OK
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Matematica_e_Computacao_Cientifica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Medicina_Veterinaria_Convencional_e_Integrativa: OK
# Ano: 2023: OK
#
# Metodos_e_Gestao_em_Avaliacao_Mestrado_Profissional: OK
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Metrologia_Cientifica_e_Industrial: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2013: OK
#
# Nanociencia_Processos_e_Materiais_Avancados: OK
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Nanotecnologia_Farmaceutica: OK
# Ano: 2014: OK
#
# Ano: 2016: OK
#
# Ano: 2021: OK
#
# Neurociencias: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Nutricao: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Oceanografia: OK
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Odontologia: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Pericias_Criminais_Ambientais_Mestrado_Profissional: OK
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Programa_de_Pos_Graduacao_Interdisciplinar_em_Ciencias_Humanas: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Programa_de_Pos_Graduacao_Multicentrico_em_Ciencias_Fisiologicas: OK
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Programa_de_Pos_Graduacao_Multidisciplinar_em_Saude_Mestrado_Profissional: OK
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Propriedade_Intelectual_e_Transferencia_de_Tecnologia_para_Inovacao_Mestrado_Profissional: OK
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Psicologia: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Quimica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Recursos_Geneticos_Vegetais: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Relacoes_Internacionais: OK
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Saude_Coletiva: OK
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Saude_Mental_e_Atencao_Psicossocial_Mestrado_Profissional: OK
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Saude_Publica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Servico_Social: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Sociologia_Politica: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Sociologia_e_Ciencia_Politica: OK
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Tecnologias_da_Informacao_e_Comunicacao: OK
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2020: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Teses_e_dissertacoes_do_Centro_Socio_Economico: OK
# Teses_e_dissertacoes_do_Centro_Tecnologico: OK
# Ano: 2004: OK
#
# Teses_e_dissertacoes_do_Centro_de_Ciencias_Agrarias: OK
# Teses_e_dissertacoes_do_Centro_de_Ciencias_Fisicas_e_Matematicas: OK
# Teses_e_dissertacoes_do_Centro_de_Ciencias_da_Saude: OK
# Teses_e_dissertacoes_do_Centro_de_Comunicacao_e_Expressao: OK
# Teses_e_dissertacoes_do_Centro_de_Filosofia_e_Ciencias_Humanas: OK
# Teses_e_dissertacoes_nao_defendidas_na_UFSC: OK
# Ano: 2003: OK
#
# Ano: 2004: OK
#
# Ano: 2005: OK
#
# Ano: 2006: OK
#
# Ano: 2008: OK
#
# Ano: 2010: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK
#
# Ano: 2018: OK
#
# Ano: 2019: OK
#
# Ano: 2021: OK
#
# Ano: 2022: OK
#
# Ano: 2023: OK
#
# Urbanismo_Historia_e_Arquitetura_da_Cidade: OK
# Ano: 2007: OK
#
# Ano: 2008: OK
#
# Ano: 2009: OK
#
# Ano: 2010: OK
#
# Ano: 2011: OK
#
# Ano: 2012: OK
#
# Ano: 2013: OK
#
# Ano: 2014: OK
#
# Ano: 2015: OK
#
# Ano: 2016: OK
#
# Ano: 2017: OK

# %% [markdown]
# # Realizando validação do processo (executar somente quando todos os programas finalizarem)

# %% [markdown]
# Caso seja encontrado incongruência entre o número total de arquivos de texto "texto_principal.txt" e entre o número de arquivos de contagem de tokens "dic_numero_tokens.msgpack" para uma dada mesma coleção, será notificado com uma mensagem no console da seguinte forma:
#
# "!!! *nome_coleção* qtd_txt *quantidade de arquivos texto_principal na coleção* qtd_tok *quantidade de arquivos dic_numeros_tokens na coleção*"

# %%
caminho_colecoes_extracao_textos = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções'

caminho_colecoes_word_embeddings = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Word Embeddings/Textos_tokenizados/Colecoes'

lista_de_colecoes_extracao = [os.path.join(caminho_colecoes_extracao_textos,colecao) for colecao in os.listdir(caminho_colecoes_extracao_textos) if ('.' not in colecao)]

lista_nomes_colecoes_extracao = [os.path.basename(colecao) for colecao in lista_de_colecoes_extracao]

dic_colecoes_extracao = {chave: valor for chave, valor in zip(lista_nomes_colecoes_extracao, lista_de_colecoes_extracao)}


for nome_colecao in sorted(dic_colecoes_extracao.keys()):

  print('\n'+'-'*100+'\n'+f'Coleção: {nome_colecao}\n'+'-'*100+'\n')
  colecao = dic_colecoes_extracao[nome_colecao]
  lista_de_anos_colecao_extracao = sorted([os.path.join(colecao,ano) for ano in os.listdir(colecao) if ano.isdigit()])

  qtd_colecao_txt = 0
  qtd_colecao_tok = 0

  for ano in lista_de_anos_colecao_extracao:

    lista_trabalhos_ano_colecao_extracao = sorted([os.path.join(ano,trabalho) for trabalho in os.listdir(ano) if trabalho.startswith('Trabalho')])

    for trabalho in lista_trabalhos_ano_colecao_extracao:
      # print(f'{os.path.basename(trabalho)}: ')
      qtd_colecao_txt += len([os.path.join(trabalho,arquivo) for arquivo in os.listdir(trabalho) if arquivo == 'texto_principal.txt'])
      qtd_colecao_tok += len([os.path.join(trabalho,arquivo) for arquivo in os.listdir(os.path.join(caminho_colecoes_word_embeddings,os.path.basename(colecao),os.path.basename(ano),os.path.basename(trabalho))) if arquivo == 'dic_numero_tokens.msgpack'])

  if qtd_colecao_txt != qtd_colecao_tok:
    print('\n!!!',nome_colecao,'qtd_txt',qtd_colecao_txt,'qtd_tok',qtd_colecao_tok,'\n')
# Out:
# ----------------------------------------------------------------------------------------------------
# Coleção: Administracao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Administracao_Universitaria_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Agroecossistemas
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Agroecossistemas_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Antropologia_Social
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Aquicultura
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Arquitetura_e_Urbanismo
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Assistencia_Farmaceutica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Biologia_Celular_e_do_Desenvolvimento
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Biologia_Vegetal
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Biologia_de_Fungos_Algas_e_Plantas
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Bioquimica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Biotecnologia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Biotecnologia_e_Biociencias
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ciencia_da_Computacao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ciencia_da_Informacao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ciencia_dos_Alimentos
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ciencia_e_Engenharia_de_Materiais
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ciencias_Medicas
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ciencias_da_Reabilitacao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Contabilidade
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Controle_de_Gestao_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Cuidados_Intensivos_e_Paliativos_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Desastres_Naturais_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Design
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Design_e_Expressao_Grafica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Direito
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Direito_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ecologia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Economia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ecossistemas_Agricolas_e_Naturais
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Educacao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Educacao_Cientifica_e_Tecnologica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Educacao_Fisica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Energia_e_Sustentabilidade
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Enfermagem
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_Ambiental
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_Ambiental_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_Civil
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_Eletrica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_Mecanica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_Mecanica_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_Quimica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_Textil
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_de_Alimentos
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_de_Automacao_e_Sistemas
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_de_Producao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_de_Sistemas_Eletronicos
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_de_Transportes_e_Gestao_Territorial
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_e_Ciencias_Mecanicas
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Engenharia_e_Gestao_do_Conhecimento
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ensino_de_Biologia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ensino_de_Biologia_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ensino_de_Fisica_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ensino_de_Historia_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Estudos_da_Traducao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Farmacia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Farmacologia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Farmacologia_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Filosofia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Fisica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Fonoaudiologia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Geografia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Geologia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Gestao_do_Cuidado_em_Enfermagem
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Gestao_do_Cuidado_em_Enfermagem_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Historia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Informatica_em_Saude_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Ingles_Estudos_Linguisticos_e_Literarios
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Jornalismo
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Letras_Ingles_e_Literatura_Correspondente
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Letras_Literatura_Brasileira
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Letras_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Linguistica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Literatura
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Matematica_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Matematica_Pura_e_Aplicada
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Matematica_e_Computacao_Cientifica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Medicina_Veterinaria_Convencional_e_Integrativa
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Metodos_e_Gestao_em_Avaliacao_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Metrologia_Cientifica_e_Industrial
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Nanociencia_Processos_e_Materiais_Avancados
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Nanotecnologia_Farmaceutica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Neurociencias
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Nutricao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Oceanografia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Odontologia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Pericias_Criminais_Ambientais_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Programa_de_Pos_Graduacao_Interdisciplinar_em_Ciencias_Humanas
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Programa_de_Pos_Graduacao_Multicentrico_em_Ciencias_Fisiologicas
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Programa_de_Pos_Graduacao_Multidisciplinar_em_Saude_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Propriedade_Intelectual_e_Transferencia_de_Tecnologia_para_Inovacao_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Psicologia
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Quimica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Recursos_Geneticos_Vegetais
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Relacoes_Internacionais
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Saude_Coletiva
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Saude_Mental_e_Atencao_Psicossocial_Mestrado_Profissional
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Saude_Publica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Servico_Social
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Sociologia_Politica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Sociologia_e_Ciencia_Politica
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Tecnologias_da_Informacao_e_Comunicacao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Teses_e_dissertacoes_do_Centro_Socio_Economico
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Teses_e_dissertacoes_do_Centro_Tecnologico
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Teses_e_dissertacoes_do_Centro_de_Ciencias_Agrarias
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Teses_e_dissertacoes_do_Centro_de_Ciencias_Fisicas_e_Matematicas
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Teses_e_dissertacoes_do_Centro_de_Ciencias_da_Saude
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Teses_e_dissertacoes_do_Centro_de_Comunicacao_e_Expressao
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Teses_e_dissertacoes_do_Centro_de_Filosofia_e_Ciencias_Humanas
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Teses_e_dissertacoes_nao_defendidas_na_UFSC
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# Coleção: Urbanismo_Historia_e_Arquitetura_da_Cidade
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Realizando contagem de tokens no corpus inteiro

# %%
caminho_colecoes_extracao_textos = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Extração de Dados/via API DSpace Protocolo OAI-PMH/Resultados/Coleções'

caminho_colecoes_word_embeddings = r'/content/drive/MyDrive/Programa - Repositório Institucional UFSC/Word Embeddings/Textos_tokenizados/Colecoes'

lista_de_colecoes_word_embeddings = [os.path.join(caminho_colecoes_word_embeddings,colecao) for colecao in os.listdir(caminho_colecoes_word_embeddings) if ('.' not in colecao)]

lista_nomes_colecoes_word_embeddings = [os.path.basename(colecao) for colecao in lista_de_colecoes_extracao]

dic_colecoes_word_embeddings = {chave: valor for chave, valor in zip(lista_nomes_colecoes_word_embeddings, lista_de_colecoes_word_embeddings)}


qtd_tokens_crus_total = 0
qtd_tokens_sem_stopwords_total = 0

for contagem,nome_colecao in enumerate(sorted(dic_colecoes_word_embeddings.keys())):
  # print('Coleções', contagem+1,'de',len(dic_colecoes_word_embeddings.keys()))

  colecao = dic_colecoes_word_embeddings[nome_colecao]
  lista_de_anos_colecao_extracao = sorted([os.path.join(colecao,ano) for ano in os.listdir(colecao) if ano.isdigit()])

  for ano in lista_de_anos_colecao_extracao:

    lista_trabalhos_ano_colecao_extracao = sorted([os.path.join(ano,trabalho) for trabalho in os.listdir(ano) if trabalho.startswith('Trabalho')])

    for trabalho in lista_trabalhos_ano_colecao_extracao:
      dic_numero_tokens_trabalho = openMsgPackFile(os.path.join(trabalho,'dic_numero_tokens.msgpack'))
      qtd_tokens_crus_total += dic_numero_tokens_trabalho['qtd_tokens_crus']
      qtd_tokens_sem_stopwords_total += dic_numero_tokens_trabalho['qtd_tokens_sem_stopwords']

  atualizarConsole(f"Coleções {contagem+1} de {len(dic_colecoes_word_embeddings.keys())}\n\nNúmero de tokens até o momento:\n\nqtd_tokens_total = {'{0:,}'.format(qtd_tokens_crus_total).replace(',','.')}\nqtd_tokens_sem_stopwords_total = {'{0:,}'.format(qtd_tokens_sem_stopwords_total).replace(',','.')}")
# Out:
# Coleções 112 de 112
#
# Número de tokens até o momento:
#
# qtd_tokens_total = 1.220.839.374
# qtd_tokens_sem_stopwords_total = 826.526.579

# %% [markdown]
# # Teste com texto manual para checar processo de contagem de tokens utilizado

# %%
texto_teste = 'Esse é um texto de teste e sei que é pequeno, mas já garante uma contagem fiel! Vou botar # caractér especial.'

dic_numero_tokens = obterNumeroDeTokens(texto_teste,silencio=False)
print('\n--- Resultado final ---\n')
for chave in dic_numero_tokens:
  print(chave,':',dic_numero_tokens[chave])
# Out:
# Lista tokens crus: ['esse', 'é', 'um', 'texto', 'de', 'teste', 'e', 'sei', 'que', 'é', 'pequeno', 'mas', 'já', 'garante', 'uma', 'contagem', 'fiel', 'vou', 'botar', 'caractér', 'especial']
# Lista vocab cru: {'sei', 'fiel', 'vou', 'especial', 'é', 'caractér', 'garante', 'botar', 'texto', 'um', 'mas', 'contagem', 'esse', 'uma', 'e', 'já', 'pequeno', 'teste', 'que', 'de'}
# Lista tokens sem stopwords: ['é', 'um', 'texto', 'teste', 'sei', 'é', 'pequeno', 'garante', 'uma', 'contagem', 'fiel', 'vou', 'botar', 'caractér', 'especial']
# Lista vocab sem stopwords: {'texto', 'teste', 'um', 'especial', 'sei', 'contagem', 'fiel', 'é', 'uma', 'caractér', 'garante', 'pequeno', 'botar', 'vou'}
#
# --- Resultado final ---
#
# qtd_tokens_crus : 21
# qtd_vocab_cru : 20
# qtd_tokens_sem_stopwords : 15
# qtd_vocab_sem_stopwords : 14
